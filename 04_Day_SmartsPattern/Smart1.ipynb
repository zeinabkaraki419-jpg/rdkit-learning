# %% [markdown]
# <a href="https://colab.research.google.com/github/zeinabkaraki419-jpg/rdkit-learning/blob/main/04_Day_SmartsPattern/Smart1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2026.3.4-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2026.3.4-cp312-cp312-manylinux_2_28_x86_64.whl (37.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.4/37.4 MB 49.4 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2026.3.4

# %%
from rdkit import Chem
from rdkit.Chem import Draw
# 1. Create a target molecule (Aspirin)
aspirin = Chem.MolFromSmiles("CC(=O)OC1=CC=CC=C1C(=O)O")
# 2. Define a SMARTS pattern for Carboxylic Acid (-C(=O)OH)
acid_pattern = Chem.MolFromSmarts("C(=O)[OH]")
# 3. Check if the pattern exists in the molecule
has_acid = aspirin.HasSubstructMatch(acid_pattern)
print(f"Contains Carboxylic Acid: {has_acid}")  # Returns True
# 4. Get atom indices where the match occurs
match_indices = aspirin.GetSubstructMatch(acid_pattern)
print(f"Matched Atom Indices: {match_indices}")
# 5. Visualize and highlight the matched substructure
img = Draw.MolToImage(
    aspirin,
    highlightAtoms=match_indices,
    legend="Aspirin (Carboxylic Acid Highlighted)"
)
display(img)
# Out:
# Contains Carboxylic Acid: True
# Matched Atom Indices: (10, 11, 12)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
# 1. Define target molecules
aspirin = Chem.MolFromSmiles("CC(=O)OC1=CC=CC=C1C(=O)O")
ethanol = Chem.MolFromSmiles("CCO")
# 2. Define SMARTS patterns
# Pattern A: Carboxylic Acid group (-C(=O)OH)
carboxylic_acid_pattern = Chem.MolFromSmarts("C(=O)[OH]")
# Pattern B: Any Aromatic Ring
aromatic_ring_pattern = Chem.MolFromSmarts("a1aaaaa1")
# 3. Check for Substructure Matches
print("=== Substructure Matching Results ===")
# Check Aspirin
has_acid = aspirin.HasSubstructMatch(carboxylic_acid_pattern)
has_aromatic = aspirin.HasSubstructMatch(aromatic_ring_pattern)
print(f"Aspirin has Carboxylic Acid: {has_acid}")     # Returns True
print(f"Aspirin has Aromatic Ring:    {has_aromatic}") # Returns True
# Check Ethanol
ethanol_has_acid = ethanol.HasSubstructMatch(carboxylic_acid_pattern)
print(f"Ethanol has Carboxylic Acid: {ethanol_has_acid}") # Returns False
# 4. Get Matching Atom Indices
# Returns tuple of atom indices matching the SMARTS pattern
matches = aspirin.GetSubstructMatches(carboxylic_acid_pattern)
print(f"Matching Atom Indices in Aspirin: {matches}")
# Out:
# === Substructure Matching Results ===
# Aspirin has Carboxylic Acid: True
# Aspirin has Aromatic Ring:    True
# Ethanol has Carboxylic Acid: False
# Matching Atom Indices in Aspirin: ((10, 11, 12),)
